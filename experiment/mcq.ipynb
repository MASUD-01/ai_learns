# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain_openai import ChatOpenAI

# %%
import os
from dotenv import load_dotenv
load_dotenv()
KEY=os.getenv("OPENAI_API_KEY")
print("KEY:", KEY)
# Out:
# KEY: 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
